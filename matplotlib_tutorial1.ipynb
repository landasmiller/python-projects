# %% [markdown]
# <a href="https://colab.research.google.com/github/landasmiller/python-projects/blob/main/matplotlib_tutorial1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

x_data = np.random.random(50) * 100
y_data = np.random.random(50) * 100

#create a scatterplot using the x and y data variables
plt.scatter(x_data, y_data, c="#000000", marker="*", s=100)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/matplotlib/markers.py in _set_marker(self, marker)
#     325             try:
# --> 326                 Path(marker)
#     327                 self._marker_function = self._set_vertices
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/path.py in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     128         """
# --> 129         vertices = _to_unmasked_float_array(vertices)
#     130         _api.check_shape((None, 2), vertices=vertices)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/cbook.py in _to_unmasked_float_array(x)
#    1344     else:
# -> 1345         return np.asarray(x, float)
#    1346
#
# ValueError: could not convert string to float: 'square'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-f751a53f3e64> in <cell line: 0>()
#       6
#       7 #create a scatterplot using the x and y data variables
# ----> 8 plt.scatter(x_data, y_data, c="#000000", marker="square", s=100)
#       9 plt.show()
#      10
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, data, **kwargs)
#    3937     **kwargs,
#    3938 ) -> PathCollection:
# -> 3939     __ret = gca().scatter(
#    3940         x,
#    3941         y,
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1519     def inner(ax, *args, data=None, **kwargs):
#    1520         if data is None:
# -> 1521             return func(
#    1522                 ax,
#    1523                 *map(cbook.sanitize_sequence, args),
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, **kwargs)
#    4943             marker_obj = marker
#    4944         else:
# -> 4945             marker_obj = mmarkers.MarkerStyle(marker)
#    4946
#    4947         path = marker_obj.get_path().transformed(
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/markers.py in __init__(self, marker, fillstyle, transform, capstyle, joinstyle)
#     246         self._user_joinstyle = JoinStyle(joinstyle) if joinstyle is not None else None
#     247         self._set_fillstyle(fillstyle)
# --> 248         self._set_marker(marker)
#     249
#     250     def _recache(self):
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/markers.py in _set_marker(self, marker)
#     327                 self._marker_function = self._set_vertices
#     328             except ValueError as err:
# --> 329                 raise ValueError(
#     330                     f'Unrecognized marker style {marker!r}') from err
#     331
#
# ValueError: Unrecognized marker style 'square'

# %%
import numpy as np
import matplotlib.pyplot as plt

years = [2006 + x for x in range(16)]
weights = [80, 83, 86, 87, 88, 92, 93, 73, 75, 77, 82, 81, 79, 90, 69, 62]

#print(len(weights))
#print(years)

#plt.plot(years, weights, c="black", lw=2, linestyle="--")
plt.plot(years, weights, "r--")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

#visualize data with a bar chart
x = ["C++", "C#", "Python", "Java", "Go"]
y = [20, 50, 140, 35, 45]

plt.bar(x, y, color="blue", width=0.5, edgecolor="red")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

ages = np.random.normal(20, 7.0, 1000)
plt.hist(ages,
         bins=20)
         #bins=[ages.min(), 18, 21, ages.max()])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

languages = ["Python", "C++", "Java", "C#", "Go"]
votes = [15, 10, 5, 20, 25]
explodes = [0.3, 0, 0, 0, 0]



plt.pie(votes, labels=languages, explode=explodes,
        autopct="%.2f%%", pctdistance=1.25)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

languages = ["Python", "C++", "Java", "C#", "Go"]
votes = [15, 10, 5, 20, 25]
explodes = [0.3, 0, 0, 0, 0]



plt.pie(votes, labels=languages, explode=explodes,
        autopct="%.2f%%", pctdistance=1.25)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# heights = np.random.normal(170, 8, 300)
# plt.boxplot(heights)
#plt.show()

first = np.linspace(0, 10, 25)
second = np.linspace(10, 200, 25)
third = np.linspace(200, 210, 25)
fourth = np.linspace(210, 230, 25)

data = np.concatenate((first, second, third, fourth))

plt.boxplot(data)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

years = [2014, 2015, 2016, 2017, 2018, 2019, 2020]
income = [40, 46, 45, 68, 70, 92, 99]

income_ticks = list(range(50, 81, 2))

plt.plot(years, income)
plt.title("Income Of Landas (in USD)", fontsize=25,fontname="DejaVu Serif")
plt.xlabel("Year")
plt.ylabel(" Yearly Income (in USD) by 000s")
#plt.yticks(income_ticks, [f"{x}K" for x in income_ticks ])

plt.show()

# %%
import matplotlib.font_manager as fm
font_names = [f.name for f in fm.fontManager.ttflist]
print(sorted(font_names))
# Out:
# ['DejaVu Sans', 'DejaVu Sans', 'DejaVu Sans', 'DejaVu Sans', 'DejaVu Sans Display', 'DejaVu Sans Mono', 'DejaVu Sans Mono', 'DejaVu Sans Mono', 'DejaVu Sans Mono', 'DejaVu Serif', 'DejaVu Serif', 'DejaVu Serif', 'DejaVu Serif', 'DejaVu Serif Display', 'Humor Sans', 'Liberation Mono', 'Liberation Mono', 'Liberation Mono', 'Liberation Mono', 'Liberation Sans', 'Liberation Sans', 'Liberation Sans', 'Liberation Sans', 'Liberation Sans Narrow', 'Liberation Sans Narrow', 'Liberation Sans Narrow', 'Liberation Sans Narrow', 'Liberation Serif', 'Liberation Serif', 'Liberation Serif', 'Liberation Serif', 'STIXGeneral', 'STIXGeneral', 'STIXGeneral', 'STIXGeneral', 'STIXNonUnicode', 'STIXNonUnicode', 'STIXNonUnicode', 'STIXNonUnicode', 'STIXSizeFiveSym', 'STIXSizeFourSym', 'STIXSizeFourSym', 'STIXSizeOneSym', 'STIXSizeOneSym', 'STIXSizeThreeSym', 'STIXSizeThreeSym', 'STIXSizeTwoSym', 'STIXSizeTwoSym', 'cmb10', 'cmex10', 'cmmi10', 'cmr10', 'cmss10', 'cmsy10', 'cmtt10']

# %%
import numpy as np
import matplotlib.pyplot as plt

stock_a = [100, 102, 99, 101, 105, 106]
stock_b = [90, 95, 102, 104, 106, 103, 109]
stock_c = [110, 115, 100, 104, 100, 98, 98]

plt.plot(stock_a, label="Company1")
plt.plot(stock_b, label="Company2")
plt.plot(stock_c, label="Company3")

plt.legend(loc="lower right")

# %%
import numpy as np
import matplotlib.pyplot as plt

votes = [10, 14, 22, 9, 17]
people = ["John", "Malcolm", "Bobby", "Claude", "Mike"]

plt.pie(votes, labels=None)
plt.legend(labels=people)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

style.use("classic")
#style.use("ggplot")
#style.use("dark_background")

votes = [10, 14, 22, 9, 17]
people = ["John", "Malcolm", "Bobby", "Claude", "Mike"]

plt.pie(votes, labels=None)
plt.legend(labels=people)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

style.use("classic")

x1, y1 = np.random.random(100), np.random.random(100)
x2, y2 = np.arange(100), np.random.random(100)

plt.figure(1)
plt.scatter(x1, y1)

plt.figure(2)
plt.plot(x2, y2)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

x = np.arange(100)

fig, axs = plt.subplots(2, 2)
axs[0, 0].plot(x, np.sin(x))
axs[0, 0].set_title("Sine Wave")

axs[0, 1].plot(x, np.cos(x))
axs[0, 1].set_title("Cosine Wave")

axs[1, 0].plot(x, np.random.random(100))
axs[1, 0].set_title("Random Function")

axs[1, 1].plot(x, np.log(x))
axs[1, 1].set_title("Log Function")
axs[1,1].set_xlabel("Test")

fig.suptitle("Four Plots")
plt.savefig("fourplots.png")

plt.show()
# Out:
# <ipython-input-19-5342df75a492>:17: RuntimeWarning: divide by zero encountered in log
#   axs[1, 1].plot(x, np.log(x))

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

ax = plt.axes(projection="3d")

x = np.random.random(100)
y = np.random.random(100)
z = np.random.random(100)

ax.scatter(x, y, z)
ax.set_title("3D Plot")
ax.set_xlabel("Test")
plt.show()
# Out:
# Text(0.5, 0.92, '3D Plot')

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

ax = plt.axes(projection="3d")

x = np.arange(0, 50, 0.1)
y = np.sin(x)
z = np.cos(x)

ax.plot(x, y, z)
ax.set_title("3D Plot")
ax.set_xlabel("Test")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

ax = plt.axes(projection="3d")

x = np.arange(-5, 5, 0.1)
y = np.arange(-5, 5, 0.1)

X, Y = np.meshgrid(x, y)
Z = np.sin(X) * np.cos(Y)

ax.plot_surface(X, Y, Z, cmap="Spectral")
ax.set_title("Surface 3D Plot")
ax.set_xlabel("Test")
#ax.view_init(azim=0, elev=90)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import random

heads_tails = [0, 0]

for _ in range(100000):
    heads_tails[random.randint(0, 1)] += 1
    plt.bar(["Heads", "Tails"], heads_tails, color=["red", "blue"])
    plt.pause(0.001)
plt.show()

#plt.pause animates the functions
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-5646390f4acf> in <cell line: 0>()
#       9     heads_tails[random.randint(0, 1)] += 1
#      10     plt.bar(["Heads", "Tails"], heads_tails, color=["red", "blue"])
# ---> 11     plt.pause(0.001)
#      12 plt.show()
#      13
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in pause(interval)
#     755         if canvas.figure.stale:
#     756             canvas.draw_idle()
# --> 757         show(block=False)
#     758         canvas.start_event_loop(interval)
#     759     else:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     612     """
#     613     _warn_if_gui_out_of_main_thread()
# --> 614     return _get_backend_mod().show(*args, **kwargs)
#     615
#     616
#
# /usr/local/lib/python3.11/dist-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      88     try:
#      89         for figure_manager in Gcf.get_all_fig_managers():
# ---> 90             display(
#      91                 figure_manager.canvas.figure,
#      92                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2156             if bbox_inches:
#    2157                 if bbox_inches == "tight":
# -> 2158                     bbox_inches = self.figure.get_tightbbox(
#    2159                         renderer, bbox_extra_artists=bbox_extra_artists)
#    2160                     if (isinstance(layout_engine, ConstrainedLayoutEngine) and
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    1846                 # need this conditional....
#    1847                 try:
# -> 1848                     bbox = ax.get_tightbbox(
#    1849                         renderer, bbox_extra_artists=bbox_extra_artists)
#    1850                 except TypeError:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4540
#    4541         for a in bbox_artists:
# -> 4542             bbox = a.get_tightbbox(renderer)
#    4543             if (bbox is not None
#    4544                     and 0 < bbox.width < np.inf
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in get_tightbbox(self, renderer)
#     362             Returns None if clipping results in no intersection.
#     363         """
# --> 364         bbox = self.get_window_extent(renderer)
#     365         if self.get_clip_on():
#     366             clip_box = self.get_clip_box()
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/spines.py in get_window_extent(self, renderer)
#     156             return bb
#     157         bboxes = [bb]
# --> 158         drawn_ticks = self.axis._update_ticks()
#     159
#     160         major_tick = next(iter({*drawn_ticks} & {*self.axis.majorTicks}), None)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axis.py in _update_ticks(self)
#    1294         major_ticks = self.get_major_ticks(len(major_locs))
#    1295         for tick, loc, label in zip(major_ticks, major_locs, major_labels):
# -> 1296             tick.update_position(loc)
#    1297             tick.label1.set_text(label)
#    1298             tick.label2.set_text(label)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axis.py in update_position(self, loc)
#     473         self.label2.set_y(loc)
#     474         self._loc = loc
# --> 475         self.stale = True
#     476
#     477     def get_view_interval(self):
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in stale(self, val)
#     324
#     325         if val and self.stale_callback is not None:
# --> 326             self.stale_callback(self, val)
#     327
#     328     def get_window_extent(self, renderer=None):
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in _stale_axes_callback(self, val)
#     102 def _stale_axes_callback(self, val):
#     103     if self.axes:
# --> 104         self.axes.stale = val
#     105
#     106
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in stale(self, val)
#     324
#     325         if val and self.stale_callback is not None:
# --> 326             self.stale_callback(self, val)
#     327
#     328     def get_window_extent(self, renderer=None):
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/figure.py in _stale_figure_callback(self, val)
#      63
#      64
# ---> 65 def _stale_figure_callback(self, val):
#      66     if (fig := self.get_figure(root=False)) is not None:
#      67         fig.stale = val
#
# KeyboardInterrupt:

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

grade = np.random.random(20)
print(grade)
# Out:
# [0.53767368 0.53450405 0.20220481 0.54029593 0.54941626 0.72152598
#  0.75138107 0.67401048 0.62676244 0.43134808 0.81939831 0.16907909
#  0.90220696 0.43544374 0.54963232 0.83114811 0.25997923 0.65557317
#  0.03950056 0.65958674]
